# %% [markdown]
# ## Artificial Neural Networks Trained on Molecular Descriptors for Predicting Toxicity

# %%
# Python ≥ 3.7 is required
import sys
assert sys.version_info >= (3, 7)

# Scikit-Learn ≥ 1.0.1 is required
import sklearn
assert sklearn.__version__ >= '1.0.1'

# TensorFlow ≥ 2.0 is required
import tensorflow as tf
print('Tensorflow version:', tf.__version__)

# Keras ≥ 2.4 is required
from tensorflow import keras
print('Keras version:', keras.__version__) 

# Common imports
import numpy as np
import os
import pandas as pd

# Sci-kit Learn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# RDKit
from rdkit import Chem
from rdkit.Chem import RDKFingerprint
from rdkit.Chem import rdMolDescriptors
# Out:
# Tensorflow version: 2.11.0
# Keras version: 2.11.0

# %% [markdown]
# ## ANN 1: Trained on Descriptors from RDKit and Mordred Libraries
#
# (with stratified k-fold cross validation)

# %%
# to produce the X dataset containing Morgan Fingerprint + RDkit descriptors 

rdkit = pandas.read_csv("data/rdkit_descriptors.csv")
rdkit = rdkit.drop(rdkit.columns[[0,1]],axis = 1) # remove first column (numbers) and second column (SMILES)
rdkit_array = np.array(rdkit)

mordred = pd.read_csv('data/mordred_descriptors.csv')
mordred = mordred.to_numpy()
mordred_array = mordred[:,2::].astype(float)

descriptors = np.append(rdkit_array, mordred_array, axis=1)

# %%
# rdkit.shape
# mordred.shape
descriptors.shape # check the shapes
# Out:
# (554, 1329)

# %%
# to get the y dataset i.e., binarised toxicity vector
original = pandas.read_csv("data/fathead_minnow_dataset.csv")
lc50 = original["LC50_(mg/L)"]

lc50_binary_list = []
for value in lc50:
    if value > 0.5:
        lc50_binary_list.append(0) # not high toxicity
    elif value <= 0.5:
        lc50_binary_list.append(1)

lc50_binary = np.array(lc50_binary_list)

# %%
seed = 42 # manually set the seed value as it is needed for the kfold set up
tf.random.set_seed(seed)  

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed) # sets up the k-fold, n_splits = 5 so its 5-fold cross validation
cvscores = [] # to record accuracy scores from each run

X = descriptors # assign your x dataset (molecular parameters)
y = lc50_binary # assign your y dataset i.e. response variables

# %%
keras.backend.clear_session() # This ensures that any previous runs don't interfere.

for train, test in kfold.split(X, y):

    ann_model1 = keras.models.Sequential([
        keras.layers.Dense(4000, input_shape=(1329,), activation = 'relu'),
        keras.layers.Dense(1000, activation = 'relu'),
        keras.layers.Dense(500, activation = 'relu'),
        keras.layers.Dense(10, activation = 'relu'),
        keras.layers.Dense(1, activation = 'sigmoid')
    ])

#     model.summary()

    ann_model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    ann_model1.fit(X[train], y[train], epochs=20, verbose=1)
    
    scores = ann_model1.evaluate(X[test], y[test], verbose=1) 
    print("%s: %.2f%%" % (ann_model1.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/20
# 14/14 [==============================] - 3s 149ms/step - loss: 186.2491 - accuracy: 0.8217
# Epoch 2/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.6864 - accuracy: 0.9187
# Epoch 3/20
# 14/14 [==============================] - 2s 121ms/step - loss: 0.6808 - accuracy: 0.9187
# Epoch 4/20
# 14/14 [==============================] - 2s 118ms/step - loss: 0.6752 - accuracy: 0.9187
# Epoch 5/20
# 14/14 [==============================] - 2s 117ms/step - loss: 0.6698 - accuracy: 0.9187
# Epoch 6/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.6643 - accuracy: 0.9187
# Epoch 7/20
# 14/14 [==============================] - 2s 119ms/step - loss: 0.6589 - accuracy: 0.9187
# Epoch 8/20
# 14/14 [==============================] - 2s 129ms/step - loss: 0.6536 - accuracy: 0.9187
# Epoch 9/20
# 14/14 [==============================] - 2s 138ms/step - loss: 0.6483 - accuracy: 0.9187
# Epoch 10/20
# 14/14 [==============================] - 2s 128ms/step - loss: 0.6432 - accuracy: 0.9187
# Epoch 11/20
# 14/14 [==============================] - 2s 118ms/step - loss: 0.6380 - accuracy: 0.9187
# Epoch 12/20
# 14/14 [==============================] - 2s 124ms/step - loss: 0.6329 - accuracy: 0.9187
# Epoch 13/20
# 14/14 [==============================] - 2s 119ms/step - loss: 0.6279 - accuracy: 0.9187
# Epoch 14/20
# 14/14 [==============================] - 2s 128ms/step - loss: 0.6229 - accuracy: 0.9187
# Epoch 15/20
# 14/14 [==============================] - 2s 128ms/step - loss: 0.6180 - accuracy: 0.9187
# Epoch 16/20
# 14/14 [==============================] - 2s 124ms/step - loss: 0.6132 - accuracy: 0.9187
# Epoch 17/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.6085 - accuracy: 0.9187
# Epoch 18/20
# 14/14 [==============================] - 2s 124ms/step - loss: 0.6037 - accuracy: 0.9187
# Epoch 19/20
# 14/14 [==============================] - 2s 120ms/step - loss: 0.5991 - accuracy: 0.9187
# Epoch 20/20
# 14/14 [==============================] - 2s 126ms/step - loss: 0.5945 - accuracy: 0.9187
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5920 - accuracy: 0.9189
# accuracy: 91.89%
# Epoch 1/20
# 14/14 [==============================] - 3s 122ms/step - loss: 2387.4438 - accuracy: 0.7810
# Epoch 2/20
# 14/14 [==============================] - 2s 120ms/step - loss: 0.6847 - accuracy: 0.9233
# Epoch 3/20
# 14/14 [==============================] - 2s 127ms/step - loss: 0.6816 - accuracy: 0.9187
# Epoch 4/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.6762 - accuracy: 0.9187
# Epoch 5/20
# 14/14 [==============================] - 2s 123ms/step - loss: 0.6710 - accuracy: 0.9187
# Epoch 6/20
# 14/14 [==============================] - 2s 138ms/step - loss: 0.6656 - accuracy: 0.9187
# Epoch 7/20
# 14/14 [==============================] - 2s 131ms/step - loss: 0.6603 - accuracy: 0.9187
# Epoch 8/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.6551 - accuracy: 0.9187
# Epoch 9/20
# 14/14 [==============================] - 2s 125ms/step - loss: 0.6498 - accuracy: 0.9187
# Epoch 10/20
# 14/14 [==============================] - 2s 168ms/step - loss: 0.6447 - accuracy: 0.9187
# Epoch 11/20
# 14/14 [==============================] - 3s 180ms/step - loss: 0.6396 - accuracy: 0.9187
# Epoch 12/20
# 14/14 [==============================] - 2s 136ms/step - loss: 0.6346 - accuracy: 0.9187
# Epoch 13/20
# 14/14 [==============================] - 2s 175ms/step - loss: 0.6295 - accuracy: 0.9187
# Epoch 14/20
# 14/14 [==============================] - 2s 134ms/step - loss: 0.6247 - accuracy: 0.9187
# Epoch 15/20
# 14/14 [==============================] - 2s 121ms/step - loss: 0.6198 - accuracy: 0.9187
# Epoch 16/20
# 14/14 [==============================] - 2s 121ms/step - loss: 0.6150 - accuracy: 0.9187
# Epoch 17/20
# 14/14 [==============================] - 2s 120ms/step - loss: 0.6102 - accuracy: 0.9187
# Epoch 18/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.6055 - accuracy: 0.9187
# Epoch 19/20
# 14/14 [==============================] - 2s 138ms/step - loss: 0.6009 - accuracy: 0.9187
# Epoch 20/20
# 14/14 [==============================] - 2s 124ms/step - loss: 0.5963 - accuracy: 0.9187
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5938 - accuracy: 0.9189
# accuracy: 91.89%
# Epoch 1/20
# 14/14 [==============================] - 3s 142ms/step - loss: 2982.8794 - accuracy: 0.7381
# Epoch 2/20
# 14/14 [==============================] - 2s 136ms/step - loss: 357.4441 - accuracy: 0.8894
# Epoch 3/20
# 14/14 [==============================] - 2s 140ms/step - loss: 16.4930 - accuracy: 0.9255
# Epoch 4/20
# 14/14 [==============================] - 2s 139ms/step - loss: 413.2041 - accuracy: 0.9210
# Epoch 5/20
# 14/14 [==============================] - 2s 123ms/step - loss: 449.4773 - accuracy: 0.9233
# Epoch 6/20
# 14/14 [==============================] - 2s 123ms/step - loss: 272.1714 - accuracy: 0.9255
# Epoch 7/20
# 14/14 [==============================] - 2s 133ms/step - loss: 106.5892 - accuracy: 0.9255
# Epoch 8/20
# 14/14 [==============================] - 2s 127ms/step - loss: 0.6529 - accuracy: 0.9255
# Epoch 9/20
# 14/14 [==============================] - 3s 191ms/step - loss: 0.6489 - accuracy: 0.9233
# Epoch 10/20
# 14/14 [==============================] - 2s 173ms/step - loss: 0.6434 - accuracy: 0.9233
# Epoch 11/20
# 14/14 [==============================] - 4s 252ms/step - loss: 0.6380 - accuracy: 0.9233
# Epoch 12/20
# 14/14 [==============================] - 3s 186ms/step - loss: 0.6327 - accuracy: 0.9233
# Epoch 13/20
# 14/14 [==============================] - 4s 257ms/step - loss: 0.6275 - accuracy: 0.9233
# Epoch 14/20
# 14/14 [==============================] - 4s 261ms/step - loss: 0.6223 - accuracy: 0.9233
# Epoch 15/20
# 14/14 [==============================] - 3s 196ms/step - loss: 0.6172 - accuracy: 0.9233
# Epoch 16/20
# 14/14 [==============================] - 3s 203ms/step - loss: 0.6122 - accuracy: 0.9233
# Epoch 17/20
# 14/14 [==============================] - 2s 156ms/step - loss: 0.6073 - accuracy: 0.9233
# Epoch 18/20
# 14/14 [==============================] - 2s 149ms/step - loss: 0.6024 - accuracy: 0.9233
# Epoch 19/20
# 14/14 [==============================] - 2s 157ms/step - loss: 0.5976 - accuracy: 0.9233
# Epoch 20/20
# 14/14 [==============================] - 2s 166ms/step - loss: 0.5930 - accuracy: 0.9233
# 4/4 [==============================] - 0s 20ms/step - loss: 894.4452 - accuracy: 0.9189
# accuracy: 91.89%
# Epoch 1/20
# 14/14 [==============================] - 4s 202ms/step - loss: 184.2616 - accuracy: 0.6659
# Epoch 2/20
# 14/14 [==============================] - 2s 126ms/step - loss: 0.6882 - accuracy: 0.9187
# Epoch 3/20
# 14/14 [==============================] - 2s 126ms/step - loss: 0.6831 - accuracy: 0.9187
# Epoch 4/20
# 14/14 [==============================] - 2s 131ms/step - loss: 0.6778 - accuracy: 0.9187
# Epoch 5/20
# 14/14 [==============================] - 2s 125ms/step - loss: 0.6725 - accuracy: 0.9187
# Epoch 6/20
# 14/14 [==============================] - 2s 169ms/step - loss: 0.6672 - accuracy: 0.9187
# Epoch 7/20
# 14/14 [==============================] - 2s 159ms/step - loss: 0.6619 - accuracy: 0.9187
# Epoch 8/20
# 14/14 [==============================] - 2s 159ms/step - loss: 0.6567 - accuracy: 0.9187
# Epoch 9/20
# 14/14 [==============================] - 2s 158ms/step - loss: 0.6515 - accuracy: 0.9187
# Epoch 10/20
# 14/14 [==============================] - 2s 160ms/step - loss: 0.6464 - accuracy: 0.9187
# Epoch 11/20
# 14/14 [==============================] - 2s 145ms/step - loss: 0.6413 - accuracy: 0.9187
# Epoch 12/20
# 14/14 [==============================] - 2s 154ms/step - loss: 0.6363 - accuracy: 0.9187
# Epoch 13/20
# 14/14 [==============================] - 2s 154ms/step - loss: 0.6313 - accuracy: 0.9187
# Epoch 14/20
# 14/14 [==============================] - 2s 159ms/step - loss: 0.6264 - accuracy: 0.9187
# Epoch 15/20
# 14/14 [==============================] - 2s 156ms/step - loss: 0.6215 - accuracy: 0.9187
# Epoch 16/20
# 14/14 [==============================] - 3s 210ms/step - loss: 0.6167 - accuracy: 0.9187
# Epoch 17/20
# 14/14 [==============================] - 2s 133ms/step - loss: 0.6120 - accuracy: 0.9187
# Epoch 18/20
# 14/14 [==============================] - 2s 131ms/step - loss: 0.6073 - accuracy: 0.9187
# Epoch 19/20
# 14/14 [==============================] - 2s 116ms/step - loss: 0.6026 - accuracy: 0.9187
# Epoch 20/20
# 14/14 [==============================] - 2s 122ms/step - loss: 0.5980 - accuracy: 0.9187
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5956 - accuracy: 0.9189
# accuracy: 91.89%
# Epoch 1/20
# 14/14 [==============================] - 3s 173ms/step - loss: 328.7875 - accuracy: 0.8131
# Epoch 2/20
# 14/14 [==============================] - 3s 179ms/step - loss: 0.6861 - accuracy: 0.9189
# Epoch 3/20
# 14/14 [==============================] - 2s 137ms/step - loss: 0.6806 - accuracy: 0.9189
# Epoch 4/20
# 14/14 [==============================] - 2s 141ms/step - loss: 0.6752 - accuracy: 0.9189
# Epoch 5/20
# 14/14 [==============================] - 2s 139ms/step - loss: 0.6697 - accuracy: 0.9189
# Epoch 6/20
# 14/14 [==============================] - 2s 134ms/step - loss: 0.6642 - accuracy: 0.9189
# Epoch 7/20
# 14/14 [==============================] - 2s 133ms/step - loss: 0.6589 - accuracy: 0.9189
# Epoch 8/20
# 14/14 [==============================] - 2s 139ms/step - loss: 0.6536 - accuracy: 0.9189
# Epoch 9/20
# 14/14 [==============================] - 2s 179ms/step - loss: 0.6483 - accuracy: 0.9189
# Epoch 10/20
# 14/14 [==============================] - 3s 203ms/step - loss: 0.6432 - accuracy: 0.9189
# Epoch 11/20
# 14/14 [==============================] - 3s 189ms/step - loss: 0.6380 - accuracy: 0.9189
# Epoch 12/20
# 14/14 [==============================] - 2s 148ms/step - loss: 0.6330 - accuracy: 0.9189
# Epoch 13/20
# 14/14 [==============================] - 2s 144ms/step - loss: 0.6280 - accuracy: 0.9189
# Epoch 14/20
# 14/14 [==============================] - 2s 136ms/step - loss: 0.6231 - accuracy: 0.9189
# Epoch 15/20
# 14/14 [==============================] - 2s 167ms/step - loss: 0.6181 - accuracy: 0.9189
# Epoch 16/20
# 14/14 [==============================] - 2s 160ms/step - loss: 0.6134 - accuracy: 0.9189
# Epoch 17/20
# 14/14 [==============================] - 2s 148ms/step - loss: 0.6085 - accuracy: 0.9189
# Epoch 18/20
# 14/14 [==============================] - 2s 146ms/step - loss: 0.6039 - accuracy: 0.9189
# Epoch 19/20
# 14/14 [==============================] - 2s 139ms/step - loss: 0.5992 - accuracy: 0.9189
# Epoch 20/20
# 14/14 [==============================] - 2s 146ms/step - loss: 0.5947 - accuracy: 0.9189
# 4/4 [==============================] - 0s 49ms/step - loss: 0.5923 - accuracy: 0.9182
# accuracy: 91.82%
# 91.88% (+/- 0.03%)

# %%
# view the results:

print(cvscores) # shows scores of each run
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores))) # shows final cross validated accuracy
# Out:
# [91.89189076423645, 91.89189076423645, 91.89189076423645, 91.89189076423645, 91.89189076423645, 91.8181836605072]
# 91.88% (+/- 0.03%)

# %% [markdown]
# ## ANN 2: Trained on Morgan Fingerprints
#
# (with stratified k-fold cross validation)

# %%
with open("data/morgan_fingerprints.csv", 'r') as file:
    file.readline()
    content = list(file)
    
fingerprints = []
for line in content:
    line_list = line.strip("\n").split(",")
    fingerprint = np.array([int(i) for i in line_list[2:]])
    fingerprints.append(fingerprint)
    
fingerprints = np.array(fingerprints)

# %%
fingerprints.shape
# Out:
# (554, 2048)

# %%
# same code as before to curate y dataset
original = pandas.read_csv("data/fathead_minnow_dataset.csv")
lc50 = original["LC50_(mg/L)"]

lc50_binary_list = []
for value in lc50:
    if value > 0.5:
        lc50_binary_list.append(0) # not high toxicity
    elif value <= 0.5:
        lc50_binary_list.append(1)

lc50_binary = np.array(lc50_binary_list)

# %%
seed = 42 # manually set the seed value as it is needed for the kfold set up
tf.random.set_seed(seed)  

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed) # sets up the k-fold, n_splits = 5 so its 5-fold cross validation
cvscores = [] # to record accuracy scores from each run

X2 = fingerprints # assign your x dataset (in this case morgan fingerprints)
y = lc50_binary # assign your y dataset i.e. response variables

# %%
keras.backend.clear_session() # This ensures that any previous runs don't interfere.

for train, test in kfold.split(X2, y):

    ann_model2 = keras.models.Sequential([
        keras.layers.Dense(4000, input_shape=(2048,), activation = 'relu'),
        keras.layers.Dense(1500, activation = 'relu'),
        keras.layers.Dense(500, activation = 'relu'),
        keras.layers.Dense(10, activation = 'relu'),
        keras.layers.Dense(1, activation = 'sigmoid')
    ])

#     model.summary()

    ann_model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    ann_model2.fit(X2[train], y[train], epochs=20, verbose=1)
    
    scores = ann_model2.evaluate(X2[test], y[test], verbose=1) 
    print("%s: %.2f%%" % (ann_model2.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/20
# 14/14 [==============================] - 5s 246ms/step - loss: 0.4674 - accuracy: 0.8555
# Epoch 2/20
# 14/14 [==============================] - 2s 175ms/step - loss: 0.2112 - accuracy: 0.9187
# Epoch 3/20
# 14/14 [==============================] - 3s 178ms/step - loss: 0.1236 - accuracy: 0.9187
# Epoch 4/20
# 14/14 [==============================] - 3s 208ms/step - loss: 0.0831 - accuracy: 0.9187
# Epoch 5/20
# 14/14 [==============================] - 4s 264ms/step - loss: 0.0711 - accuracy: 0.9391
# Epoch 6/20
# 14/14 [==============================] - 3s 183ms/step - loss: 0.0667 - accuracy: 0.9932
# Epoch 7/20
# 14/14 [==============================] - 3s 181ms/step - loss: 0.0559 - accuracy: 0.9887
# Epoch 8/20
# 14/14 [==============================] - 2s 173ms/step - loss: 0.0222 - accuracy: 0.9910
# Epoch 9/20
# 14/14 [==============================] - 3s 182ms/step - loss: 0.0193 - accuracy: 0.9932
# Epoch 10/20
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0172 - accuracy: 0.9910
# Epoch 11/20
# 14/14 [==============================] - 3s 233ms/step - loss: 0.0175 - accuracy: 0.9887
# Epoch 12/20
# 14/14 [==============================] - 3s 205ms/step - loss: 0.0179 - accuracy: 0.9932
# Epoch 13/20
# 14/14 [==============================] - 3s 200ms/step - loss: 0.0159 - accuracy: 0.9932
# Epoch 14/20
# 14/14 [==============================] - 3s 210ms/step - loss: 0.0157 - accuracy: 0.9932
# Epoch 15/20
# 14/14 [==============================] - 3s 211ms/step - loss: 0.0163 - accuracy: 0.9932
# Epoch 16/20
# 14/14 [==============================] - 3s 183ms/step - loss: 0.0148 - accuracy: 0.9932
# Epoch 17/20
# 14/14 [==============================] - 3s 184ms/step - loss: 0.0163 - accuracy: 0.9932
# Epoch 18/20
# 14/14 [==============================] - 4s 261ms/step - loss: 0.0149 - accuracy: 0.9910
# Epoch 19/20
# 14/14 [==============================] - 3s 199ms/step - loss: 0.0166 - accuracy: 0.9932
# Epoch 20/20
# 14/14 [==============================] - 3s 196ms/step - loss: 0.0151 - accuracy: 0.9932
# 4/4 [==============================] - 0s 30ms/step - loss: 0.7640 - accuracy: 0.9189
# accuracy: 91.89%
# Epoch 1/20
# 14/14 [==============================] - 4s 185ms/step - loss: 0.4046 - accuracy: 0.9187
# Epoch 2/20
# 14/14 [==============================] - 3s 198ms/step - loss: 0.1589 - accuracy: 0.9187
# Epoch 3/20
# 14/14 [==============================] - 3s 207ms/step - loss: 0.0763 - accuracy: 0.9187
# Epoch 4/20
# 14/14 [==============================] - 2s 175ms/step - loss: 0.0719 - accuracy: 0.9391
# Epoch 5/20
# 14/14 [==============================] - 4s 261ms/step - loss: 0.0719 - accuracy: 0.9932
# Epoch 6/20
# 14/14 [==============================] - 5s 335ms/step - loss: 0.0666 - accuracy: 0.9932
# Epoch 7/20
# 14/14 [==============================] - 4s 258ms/step - loss: 0.0649 - accuracy: 0.9887
# Epoch 8/20
# 14/14 [==============================] - 3s 206ms/step - loss: 0.0677 - accuracy: 0.9955
# Epoch 9/20
# 14/14 [==============================] - 2s 177ms/step - loss: 0.0665 - accuracy: 0.9932
# Epoch 10/20
# 14/14 [==============================] - 3s 202ms/step - loss: 0.0642 - accuracy: 0.9955
# Epoch 11/20
# 14/14 [==============================] - 4s 285ms/step - loss: 0.0646 - accuracy: 0.9955
# Epoch 12/20
# 14/14 [==============================] - 3s 238ms/step - loss: 0.0645 - accuracy: 0.9955
# Epoch 13/20
# 14/14 [==============================] - 4s 273ms/step - loss: 0.0627 - accuracy: 0.9955
# Epoch 14/20
# 14/14 [==============================] - 5s 329ms/step - loss: 0.0625 - accuracy: 0.9955
# Epoch 15/20
# 14/14 [==============================] - 3s 251ms/step - loss: 0.0634 - accuracy: 0.9955
# Epoch 16/20
# 14/14 [==============================] - 4s 295ms/step - loss: 0.0605 - accuracy: 0.9955
# Epoch 17/20
# 14/14 [==============================] - 3s 226ms/step - loss: 0.0603 - accuracy: 0.9955
# Epoch 18/20
# 14/14 [==============================] - 3s 232ms/step - loss: 0.0620 - accuracy: 0.9955
# Epoch 19/20
# 14/14 [==============================] - 3s 205ms/step - loss: 0.0595 - accuracy: 0.9955
# Epoch 20/20
# 14/14 [==============================] - 3s 194ms/step - loss: 0.0623 - accuracy: 0.9955
# 4/4 [==============================] - 0s 31ms/step - loss: 0.7445 - accuracy: 0.9279
# accuracy: 92.79%
# Epoch 1/20
# 14/14 [==============================] - 4s 198ms/step - loss: 0.3315 - accuracy: 0.8826
# Epoch 2/20
# 14/14 [==============================] - 3s 191ms/step - loss: 0.1355 - accuracy: 0.9187
# Epoch 3/20
# 14/14 [==============================] - 3s 234ms/step - loss: 0.0899 - accuracy: 0.9458
# Epoch 4/20
# 14/14 [==============================] - 3s 211ms/step - loss: 0.0650 - accuracy: 0.9842
# Epoch 5/20
# 14/14 [==============================] - 3s 187ms/step - loss: 0.0330 - accuracy: 0.9842
# Epoch 6/20
# 14/14 [==============================] - 3s 210ms/step - loss: 0.0210 - accuracy: 0.9887
# Epoch 7/20
# 14/14 [==============================] - 3s 234ms/step - loss: 0.0243 - accuracy: 0.9887
# Epoch 8/20
# 14/14 [==============================] - 3s 241ms/step - loss: 0.0199 - accuracy: 0.9910
# Epoch 9/20
# 14/14 [==============================] - 3s 229ms/step - loss: 0.0183 - accuracy: 0.9910
# Epoch 10/20
# 14/14 [==============================] - 4s 254ms/step - loss: 0.0177 - accuracy: 0.9910
# Epoch 11/20
# 14/14 [==============================] - 4s 252ms/step - loss: 0.0185 - accuracy: 0.9910
# Epoch 12/20
# 14/14 [==============================] - 3s 214ms/step - loss: 0.0187 - accuracy: 0.9910
# Epoch 13/20
# 14/14 [==============================] - 4s 248ms/step - loss: 0.0169 - accuracy: 0.9910
# Epoch 14/20
# 14/14 [==============================] - 3s 202ms/step - loss: 0.0168 - accuracy: 0.9910
# Epoch 15/20
# 14/14 [==============================] - 4s 294ms/step - loss: 0.0380 - accuracy: 0.9910
# Epoch 16/20
# 14/14 [==============================] - 4s 295ms/step - loss: 0.0251 - accuracy: 0.9887
# Epoch 17/20
# 14/14 [==============================] - 5s 326ms/step - loss: 0.0205 - accuracy: 0.9910
# Epoch 18/20
# 14/14 [==============================] - 3s 237ms/step - loss: 0.0223 - accuracy: 0.9910
# Epoch 19/20
# 14/14 [==============================] - 3s 216ms/step - loss: 0.0183 - accuracy: 0.9910
# Epoch 20/20
# 14/14 [==============================] - 3s 199ms/step - loss: 0.0262 - accuracy: 0.9910
# 4/4 [==============================] - 0s 24ms/step - loss: 0.8435 - accuracy: 0.9279
# accuracy: 92.79%
# Epoch 1/20
# 14/14 [==============================] - 4s 191ms/step - loss: 0.3916 - accuracy: 0.8713
# Epoch 2/20
# 14/14 [==============================] - 3s 194ms/step - loss: 0.1472 - accuracy: 0.9187
# Epoch 3/20
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0733 - accuracy: 0.9797
# Epoch 4/20
# 14/14 [==============================] - 3s 185ms/step - loss: 0.0517 - accuracy: 0.9955
# Epoch 5/20
# 14/14 [==============================] - 3s 204ms/step - loss: 0.0291 - accuracy: 0.9910
# Epoch 6/20
# 14/14 [==============================] - 3s 234ms/step - loss: 0.0206 - accuracy: 0.9910
# Epoch 7/20
# 14/14 [==============================] - 3s 197ms/step - loss: 0.0124 - accuracy: 0.9910
# Epoch 8/20
# 14/14 [==============================] - 3s 231ms/step - loss: 0.0146 - accuracy: 0.9887
# Epoch 9/20
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0107 - accuracy: 0.9910
# Epoch 10/20
# 14/14 [==============================] - 3s 181ms/step - loss: 0.0115 - accuracy: 0.9842
# Epoch 11/20
# 14/14 [==============================] - 3s 182ms/step - loss: 0.0111 - accuracy: 0.9887
# Epoch 12/20
# 14/14 [==============================] - 3s 186ms/step - loss: 0.0111 - accuracy: 0.9887
# Epoch 13/20
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0110 - accuracy: 0.9932
# Epoch 14/20
# 14/14 [==============================] - 3s 201ms/step - loss: 0.0110 - accuracy: 0.9932
# Epoch 15/20
# 14/14 [==============================] - 3s 206ms/step - loss: 0.0110 - accuracy: 0.9932
# Epoch 16/20
# 14/14 [==============================] - 3s 224ms/step - loss: 0.0110 - accuracy: 0.9932
# Epoch 17/20
# 14/14 [==============================] - 3s 201ms/step - loss: 0.0109 - accuracy: 0.9932
# Epoch 18/20
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0109 - accuracy: 0.9932
# Epoch 19/20
# 14/14 [==============================] - 3s 178ms/step - loss: 0.0110 - accuracy: 0.9932
# Epoch 20/20
# 14/14 [==============================] - 3s 192ms/step - loss: 0.0109 - accuracy: 0.9932
# 4/4 [==============================] - 0s 21ms/step - loss: 1.1055 - accuracy: 0.9279
# accuracy: 92.79%
# Epoch 1/20
# 14/14 [==============================] - 5s 268ms/step - loss: 0.4115 - accuracy: 0.8694
# Epoch 2/20
# 14/14 [==============================] - 5s 354ms/step - loss: 0.1676 - accuracy: 0.9189
# Epoch 3/20
# 14/14 [==============================] - 3s 193ms/step - loss: 0.0824 - accuracy: 0.9189
# Epoch 4/20
# 14/14 [==============================] - 4s 266ms/step - loss: 0.0699 - accuracy: 0.9234
# Epoch 5/20
# 14/14 [==============================] - 3s 217ms/step - loss: 0.0664 - accuracy: 0.9865
# Epoch 6/20
# 14/14 [==============================] - 3s 188ms/step - loss: 0.0653 - accuracy: 0.9887
# Epoch 7/20
# 14/14 [==============================] - 3s 191ms/step - loss: 0.0644 - accuracy: 0.9910
# Epoch 8/20
# 14/14 [==============================] - 4s 257ms/step - loss: 0.0685 - accuracy: 0.9887
# Epoch 9/20
# 14/14 [==============================] - 4s 260ms/step - loss: 0.0644 - accuracy: 0.9887
# Epoch 10/20
# 14/14 [==============================] - 3s 238ms/step - loss: 0.0637 - accuracy: 0.9887
# Epoch 11/20
# 14/14 [==============================] - 4s 256ms/step - loss: 0.0633 - accuracy: 0.9887
# Epoch 12/20
# 14/14 [==============================] - 4s 276ms/step - loss: 0.0628 - accuracy: 0.9887
# Epoch 13/20
# 14/14 [==============================] - 4s 273ms/step - loss: 0.0668 - accuracy: 0.9887
# Epoch 14/20
# 14/14 [==============================] - 3s 233ms/step - loss: 0.0626 - accuracy: 0.9887
# Epoch 15/20
# 14/14 [==============================] - 4s 276ms/step - loss: 0.0629 - accuracy: 0.9865
# Epoch 16/20
# 14/14 [==============================] - 3s 189ms/step - loss: 0.0630 - accuracy: 0.9887
# Epoch 17/20
# 14/14 [==============================] - 3s 228ms/step - loss: 0.0618 - accuracy: 0.9887
# Epoch 18/20
# 14/14 [==============================] - 4s 270ms/step - loss: 0.0622 - accuracy: 0.9887
# Epoch 19/20
# 14/14 [==============================] - 3s 236ms/step - loss: 0.0613 - accuracy: 0.9887
# Epoch 20/20
# 14/14 [==============================] - 3s 203ms/step - loss: 0.0611 - accuracy: 0.9887
# 4/4 [==============================] - 0s 21ms/step - loss: 0.8691 - accuracy: 0.9273
# accuracy: 92.73%
# 92.60% (+/- 0.35%)

# %%
# view the results:

print(cvscores) # shows scores of each run
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores))) # shows final cross validated accuracy
# Out:
# [91.89189076423645, 92.79279112815857, 92.79279112815857, 92.79279112815857, 92.72727370262146]
# 92.60% (+/- 0.35%)
